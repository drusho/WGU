# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("churn_clean.csv")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    CaseOrder Customer_id                           Interaction  \
# 0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
#
#                                 UID         City State                 County  \
# 0  e885b299883d4f9fb18e39c75155d990  Point Baker    AK  Prince of Wales-Hyder
# 1  f2de8bef964785f41a2959829830fb8a  West Branch    MI                 Ogemaw
# 2  f1784cfa9f6d92ae816197eb175d3c71      Yamhill    OR                Yamhill
# 3  dc8a365077241bb5cd5ccd305136b05e      Del Mar    CA              San Diego
# 4  aabb64a116e83fdc4befc1fbab1663f9    Needville    TX              Fort Bend
#
#      Zip       Lat        Lng  Population      Area             TimeZone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CaseOrder             10000 non-null  int64
#  1   Customer_id           10000 non-null  object
#  2   Interaction           10000 non-null  object
#  3   UID                   10000 non-null  object
#  4   City                  10000 non-null  object
#  5   State                 10000 non-null  object
#  6   County                10000 non-null  object
#  7   Zip                   10000 non-null  int64
#  8   Lat                   10000 non-null  float64
#  9   Lng                   10000 non-null  float64
#  10  Population            10000 non-null  int64
#  11  Area                  10000 non-null  object
#  12  TimeZone              10000 non-null  object
#  13  Job                   10000 non-null  object
#  14  Children              10000 non-null  int64
# ...

# %%
df.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.describe()
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  49153.319600     38.757567    -90.782536    9756.562400
# std     2886.89568  27532.196108      5.437389     15.156142   14432.698671
# min        1.00000    601.000000     17.966120   -171.688150       0.000000
# 25%     2500.75000  26292.500000     35.341828    -97.082812     738.000000
# 50%     5000.50000  48869.500000     39.395800    -87.918800    2910.500000
# 75%     7500.25000  71866.500000     42.106908    -80.088745   13168.000000
# max    10000.00000  99929.000000     70.640660    -65.667850  111850.000000
#
#          Children           Age         Income  Outage_sec_perweek  \
# count  10000.0000  10000.000000   10000.000000        10000.000000
# mean       2.0877     53.078400   39806.926771           10.001848
# std        2.1472     20.698882   28199.916702            2.976019
# ...

# %%
df.isnull().sum()
# Out:
# CaseOrder               0
# Customer_id             0
# Interaction             0
# UID                     0
# City                    0
# State                   0
# County                  0
# Zip                     0
# Lat                     0
# Lng                     0
# Population              0
# Area                    0
# TimeZone                0
# Job                     0
# Children                0
# Age                     0
# Income                  0
# Marital                 0
# Gender                  0
# Churn                   0
# Outage_sec_perweek      0
# Email                   0
# Contacts                0
# Yearly_equip_failure    0
# Techie                  0
# Contract                0
# Port_modem              0
# Tablet                  0
# InternetService         0
# Phone                   0
# Multiple                0
# OnlineSecurity          0
# OnlineBackup            0
# DeviceProtection        0
# TechSupport             0
# ...

# %%
df.columns
# Out:
# Index(['CaseOrder', 'Customer_id', 'Interaction', 'UID', 'City', 'State',
#        'County', 'Zip', 'Lat', 'Lng', 'Population', 'Area', 'TimeZone', 'Job',
#        'Children', 'Age', 'Income', 'Marital', 'Gender', 'Churn',
#        'Outage_sec_perweek', 'Email', 'Contacts', 'Yearly_equip_failure',
#        'Techie', 'Contract', 'Port_modem', 'Tablet', 'InternetService',
#        'Phone', 'Multiple', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'PaymentMethod', 'Tenure', 'MonthlyCharge',
#        'Bandwidth_GB_Year', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5',
#        'Item6', 'Item7', 'Item8'],
#       dtype='object')

# %%
df.drop(['CaseOrder', 'Interaction', 'UID', 'Population', 'Area', 'TimeZone',
         'Income', 'Outage_sec_perweek', 'Email', 'Contacts', 'Yearly_equip_failure',
       'Techie', 'Port_modem', 'Tablet', 'Marital', 'Job', 'Multiple',
       'Bandwidth_GB_Year', 'Item1', 'Item2', 'Item3', 'Item4', 'Item5',
       'Item6', 'Item7', 'Item8'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (10000, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_id       10000 non-null  object
#  1   City              10000 non-null  object
#  2   State             10000 non-null  object
#  3   County            10000 non-null  object
#  4   Zip               10000 non-null  int64
#  5   Lat               10000 non-null  float64
#  6   Lng               10000 non-null  float64
#  7   Children          10000 non-null  int64
#  8   Age               10000 non-null  int64
#  9   Gender            10000 non-null  object
#  10  Churn             10000 non-null  object
#  11  Contract          10000 non-null  object
#  12  InternetService   10000 non-null  object
#  13  Phone             10000 non-null  object
#  14  OnlineSecurity    10000 non-null  object
#  15  OnlineBackup      10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Zip           Lat           Lng    Children           Age  \
# count  10000.000000  10000.000000  10000.000000  10000.0000  10000.000000
# mean   49153.319600     38.757567    -90.782536      2.0877     53.078400
# std    27532.196108      5.437389     15.156142      2.1472     20.698882
# min      601.000000     17.966120   -171.688150      0.0000     18.000000
# 25%    26292.500000     35.341828    -97.082812      0.0000     35.000000
# 50%    48869.500000     39.395800    -87.918800      1.0000     53.000000
# 75%    71866.500000     42.106908    -80.088745      3.0000     71.000000
# max    99929.000000     70.640660    -65.667850     10.0000     89.000000
#
#              Tenure  MonthlyCharge
# count  10000.000000   10000.000000
# mean      34.526188     172.624816
# std       26.443063      42.943094
# min        1.000259      79.978860
# 25%        7.917694     139.979239
# 50%       35.430507     167.484700
# 75%       61.479795     200.734725
# ...

# %%
df['OnlineSecurity']=df['OnlineSecurity'].astype('category')
df['OnlineSecurity']=df['OnlineSecurity'].cat.codes

# %%
df['OnlineBackup']=df['OnlineBackup'].astype('category')
df['OnlineBackup']=df['OnlineBackup'].cat.codes

# %%
df['DeviceProtection']=df['DeviceProtection'].astype('category')
df['DeviceProtection']=df['DeviceProtection'].cat.codes

# %%
df['TechSupport']=df['TechSupport'].astype('category')
df['TechSupport']=df['TechSupport'].cat.codes

# %%
df['StreamingTV']=df['StreamingTV'].astype('category')
df['StreamingTV']=df['StreamingTV'].cat.codes

# %%
df['StreamingMovies']=df['StreamingMovies'].astype('category')
df['StreamingMovies']=df['StreamingMovies'].cat.codes

# %%
df.Age = np.where(df.Age > 55, "Senior Citizen",
                               np.where(df.Age < 54, "Adult", "Adult"))

# %%
df.describe()
# Out:
#                 Zip           Lat           Lng    Children  OnlineSecurity  \
# count  10000.000000  10000.000000  10000.000000  10000.0000    10000.000000
# mean   49153.319600     38.757567    -90.782536      2.0877        0.357600
# std    27532.196108      5.437389     15.156142      2.1472        0.479317
# min      601.000000     17.966120   -171.688150      0.0000        0.000000
# 25%    26292.500000     35.341828    -97.082812      0.0000        0.000000
# 50%    48869.500000     39.395800    -87.918800      1.0000        0.000000
# 75%    71866.500000     42.106908    -80.088745      3.0000        1.000000
# max    99929.000000     70.640660    -65.667850     10.0000        1.000000
#
#        OnlineBackup  DeviceProtection   TechSupport   StreamingTV  \
# count  10000.000000      10000.000000  10000.000000  10000.000000
# mean       0.450600          0.438600      0.375000      0.492900
# std        0.497579          0.496241      0.484147      0.499975
# ...

# %%
df['Age'].unique()
# Out:
# array(['Senior Citizen', 'Adult'], dtype=object)

# %%
df.to_csv(r'Churn_cleanAF.csv')
